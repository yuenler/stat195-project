# %%
import numpy as np
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\utilities")

from plot_papers import plot_papers

# %% [markdown]
# # Line Plot

# %% [markdown]
# # Full Season

# %%
evaluation_results_bs = [[0.145,0.15,0.15,0.144],[0.198,0.2,0.201,0.197],[0.22,0.209,0.208,0.209],
                         [0.216,0.205,0.21,0.209]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_bs,
                                                   'Brier Score of Full Information Models 2017-2018',
                                                   'Brier Score', loc=1, ylimit=0.25)
plt.savefig('Figures/line_plot_bs_full_season.png')
plt.show()

# %%
evaluation_results_acc = [[0.77,0.755,0.779,0.784],[0.697,0.713,0.709,0.719],[0.662,0.665,0.692,0.681],
                          [0.641,0.668,0.69,0.668]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_acc,
                                                   'Accuracy of Full Information Models 2017-2018',
                                                   'Accuracy',loc=1, ylimit=0.85)
plt.savefig('Figures/line_plot_acc_full_season.png')
plt.show()

# %%
evaluation_results_f1 = [[0.833, 0.818, 0.833, 0.839],[0.763, 0.783, 0.784, 0.788],[0.77, 0.749, 0.778, 0.774],
                         [0.748, 0.761, 0.759, 0.753]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_f1,
                                                   'F1-score of Full Information Models 2017-2018',
                                                   'F1-score', loc=1, ylimit=0.88)
plt.savefig('Figures/line_plot_f1_full_season.png')
plt.show()

# %% [markdown]
# ## Middle Season

# %%
evaluation_results_bs = [[0.146,0.151,0.171,0.152],[0.205,0.22,0.223,0.209],[0.215,0.238,0.221,0.219],
                         [0.235,0.206,0.203,0.21]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_bs,
                                                   'Brier Score of Full Information Models Middle Season 2017-2018',
                                                   'Brier Score', loc=1, ylimit=0.26)
plt.savefig('Figures/line_plot_bs_middle_season.png')
plt.show()

# %%
evaluation_results_acc = [[0.78,0.747,0.747,0.78],[0.712,0.686,0.614,0.693],[0.683,0.6,0.658,0.692],
                          [0.571,0.726,0.679,0.667]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_acc,
                                                   'Accuracy of Full Information Models Middle Season 2017-2018',
                                                   'Accuracy',loc=1, ylimit=0.86)
plt.savefig('Figures/line_plot_acc_middle_season.png')
plt.show()

# %%
evaluation_results_f1 = [[0.841, 0.813, 0.824, 0.841],[0.798, 0.769, 0.751, 0.789],[0.793, 0.733, 0.781, 0.804],
                         [0.723, 0.793, 0.765, 0.763]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_f1,
                                                   'F1-score of Full Information Models Middle Season 2017-2018',
                                                   'F1-score', loc=1, ylimit=0.90)
plt.savefig('Figures/line_plot_f1_middle_season.png')
plt.show()

# %% [markdown]
# ## Play Offs

# %%
evaluation_results_bs = [[0.148,0.132,0.125,0.132],[0.249,0.232,0.217,0.229],[0.226,0.192,0.206,0.204],
                         [0.191,0.165,0.179,0.174]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_bs,
                                                   'Brier Score of Full Information Models Play Offs 2017-2018',
                                                   'Brier Score', loc=1, ylimit=0.27)
plt.savefig('Figures/line_plot_bs_play_offs.png')
plt.show()

# %%
evaluation_results_acc = [[0.818,0.773,0.864,0.818],[0.571,0.524,0.667,0.571],[0.65,0.7,0.75,0.75],
                          [0.75,0.75,0.688,0.75]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_acc,
                                                   'Accuracy of Full Information Models Play Offs 2017-2018',
                                                   'Accuracy',loc=1, ylimit=0.97)
plt.savefig('Figures/line_plot_acc_play_offs.png')
plt.show()

# %%
evaluation_results_f1 = [[0.857, 0.815, 0.889, 0.857],[0.71, 0.668, 0.759, 0.71],[0.774, 0.813, 0.839, 0.839],
                         [0.846, 0.818, 0.783, 0.833]]

plt = plot_papers().line_plot_tournament_per_model(evaluation_results_f1,
                                                   'F1-score of Full Information Models Play Offs 2017-2018',
                                                   'F1-score', loc=1, ylimit=0.96)
plt.savefig('Figures/line_plot_f1_play_offs.png')
plt.show()

# %% [markdown]
# # Difference Baseline and Full Information Models

# %%
full_information_model_rps = [0.144, 0.197, 0.208, 0.205]
baseline_rps = [0.167, 0.208, 0.213, 0.232]
differences_rps = np.subtract(baseline_rps,full_information_model_rps)
full_information_model_acc = [0.784, 0.719, 0.692, 0.69]
baseline_acc = [0.745, 0.688, 0.665, 0.636]
differences_acc = np.subtract(full_information_model_acc,baseline_acc)
full_information_model_f1 = [0.839, 0.788, 0.778, 0.761]
baseline_f1 = [0.814, 0.769, 0.767, 0.729]
differences_f1 = np.subtract(full_information_model_f1,baseline_f1)

differences = [differences_rps,differences_acc,differences_f1]

title = 'Differences of Best Predictive Model for \n Full Information Models  with Baseline Vanilla Models 2017-2018'

plt = plot_papers().line_plot_difference_baseline_full_information_model(differences,title,loc=1, ylimit=0.07)


plt.savefig('Figures/baseline_vs_full_information_full_season.png')
plt.show()

# %% [markdown]
# ## Middle Season

# %%
full_information_model_rps = [0.146, 0.205, 0.219, 0.203]
baseline_rps = [0.171, 0.21, 0.204, 0.216]
differences_rps = np.subtract(baseline_rps,full_information_model_rps)
full_information_model_acc = [0.78, 0.712, 0.692, 0.726]
baseline_acc = [0.747, 0.686, 0.692, 0.667]
differences_acc = np.subtract(full_information_model_acc,baseline_acc)
full_information_model_f1 = [0.841, 0.798, 0.804, 0.793]
baseline_f1 = [0.827, 0.774, 0.776, 0.754]
differences_f1 = np.subtract(full_information_model_f1,baseline_f1)

differences = [differences_rps,differences_acc,differences_f1]

title = 'Differences of Best Predictive Model for \n Full Information Models  with Baseline Vanilla Models Middle Season 2017-2018'

plt = plot_papers().line_plot_difference_baseline_full_information_model(differences,title,loc=1, ylimit=0.08)


plt.savefig('Figures/baseline_vs_full_information_middle_season.png')
plt.show()

# %% [markdown]
# ## Play offs

# %%
full_information_model_rps = [0.125, 0.217, 0.192, 0.165]
baseline_rps = [0.16, 0.19, 0.221, 0.168]
differences_rps = np.subtract(baseline_rps,full_information_model_rps)
full_information_model_acc = [0.864, 0.667, 0.75, 0.75]
baseline_acc = [0.773, 0.714, 0.7, 0.75]
differences_acc = np.subtract(full_information_model_acc,baseline_acc)
full_information_model_f1 = [0.889, 0.759, 0.839, 0.846]
baseline_f1 = [0.815, 0.786, 0.8, 0.833]
differences_f1 = np.subtract(full_information_model_f1,baseline_f1)

differences = [differences_rps,differences_acc,differences_f1]


title = 'Differences of Best Predictive Model for \n Full Information Models  with Baseline Vanilla Models Play Offs 2017-2018'

plt = plot_papers().line_plot_difference_baseline_full_information_model(differences,title,loc=1, ylimit=0.1)


plt.savefig('Figures/baseline_vs_full_information_play_offs.png')
plt.show()

# %% [markdown]
# # Comparison Train with All previous years vs Train with same Year

# %% [markdown]
# ## Middle Season

# %% [markdown]
# ### Brier Score

# %%
import numpy as np
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\utilities")

from plot_papers import plot_papers

# %%
full_greek_all = [0.138,0.138,0.136,0.134]
full_greek_same = [0.146,0.151,0.171,0.152]
full_spain_all = [0.178,0.187,0.185,0.181]
full_spain_same = [0.205,0.22,0.223,0.209]
full_euroleague_all = [0.205,0.201,0.211,0.203]
full_euroleague_same = [0.215,0.238,0.221,0.219]
full_eurocup_all = [0.233,0.227,0.218,0.222]
full_eurocup_same = [0.235,0.206,0.203,0.21]


baseline_greek_all = [0.15,0.158,0.154,0.152]
baseline_greek_same = [0.189,0.171,0.179,0.175]
baseline_spain_all = [0.202,0.208,0.211,0.205]
baseline_spain_same = [0.214,0.214,0.22,0.21]
baseline_euroleague_all = [0.204,0.206,0.207,0.204]
baseline_euroleague_same = [0.212,0.214,0.204,0.207]
baseline_eurocup_all = [0.219,0.24,0.229,0.226]
baseline_eurocup_same = [0.216,0.235,0.25,0.225]

# %%
title = 'Mid-Season Brier Score \n Comparison The Length of Training Set'

plt = plot_papers().barplot_comparison_train_set(full_greek_all, full_greek_same,full_spain_all,full_spain_same ,
                                                 full_euroleague_all,full_euroleague_same,full_eurocup_all,
                                                 full_eurocup_same, baseline_greek_all, baseline_greek_same,
                                                 baseline_spain_all, baseline_spain_same, baseline_euroleague_all ,
                                                 baseline_euroleague_same, baseline_eurocup_all, baseline_eurocup_same, 
                                                 title, 'Brier Score','Mid-Season', loc=1,
                                                letters_position=-0.015, ylimit=0.37)

plt.savefig('Figures/bs_comparison_train_set_mid_season.png')
plt.show()

# %% [markdown]
# ### Accuracy

# %%
full_greek_all = [0.802,0.802,0.78,0.791]
full_greek_same = [0.78,0.747,0.747,0.78]
full_spain_all = [0.745,0.739,0.752,0.752]
full_spain_same = [0.712,0.686,0.614,0.693]
full_euroleague_all = [0.692,0.692,0.708,0.717]
full_euroleague_same = [0.683,0.6,0.658,0.692]
full_eurocup_all = [0.56,0.595,0.643,0.583]
full_eurocup_same = [0.571,0.726,0.679,0.667]


baseline_greek_all = [0.78,0.758,0.78,0.791]
baseline_greek_same = [0.703,0.725,0.736,0.747]
baseline_spain_all = [0.699,0.673,0.68,0.699]
baseline_spain_same = [0.647,0.673,0.634,0.686]
baseline_euroleague_all = [0.658,0.667,0.667,0.65]
baseline_euroleague_same = [0.667,0.65,0.692,0.675]
baseline_eurocup_all = [0.702,0.643,0.643,0.643]
baseline_eurocup_same = [0.607,0.667, 0.56,0.607]

# %%
title = 'Mid-Season Accuracy \n Comparison The Length of Training Set'

plt = plot_papers().barplot_comparison_train_set(full_greek_all, full_greek_same,full_spain_all,full_spain_same ,
                                                 full_euroleague_all,full_euroleague_same,full_eurocup_all,
                                                 full_eurocup_same, baseline_greek_all, baseline_greek_same,
                                                 baseline_spain_all, baseline_spain_same, baseline_euroleague_all ,
                                                 baseline_euroleague_same, baseline_eurocup_all, baseline_eurocup_same, 
                                                 title, 'Accuracy', 'Mid-Season', loc=1,letters_position=-0.045,
                                                ylimit=1.1)

plt.savefig('Figures/acc_comparison_train_set_mid_season.png')
plt.show()

# %% [markdown]
# ### F1-Score

# %%
full_greek_all = [0.855,0.852,0.836,0.846]
full_greek_same = [0.841,0.813,0.824,0.841]
full_spain_all = [0.796,0.8,0.814,0.808]
full_spain_same = [0.798,0.769,0.751,0.789]
full_euroleague_all = [0.789,0.77,0.785,0.8]
full_euroleague_same = [0.793,0.733,0.781,0.804]
full_eurocup_all = [0.718,0.707,0.737,0.706]
full_eurocup_same = [0.723,0.793,0.765,0.763]


baseline_greek_all = [0.841,0.828,0.841,0.85]
baseline_greek_same = [0.809,0.809,0.812,0.827]
baseline_spain_all = [0.775,0.747,0.749,0.772]
baseline_spain_same = [0.745,0.75,0.723,0.774]
baseline_euroleague_all = [0.754,0.773,0.775,0.756]
baseline_euroleague_same = [0.762,0.753,0.776,0.766]
baseline_eurocup_all = [0.762,0.737,0.737,0.737]
baseline_eurocup_same = [0.723,0.754, 0.718,0.732]

# %%
title = 'Mid-Season F1-Score \n Comparison The Length of Training Set'

plt = plot_papers().barplot_comparison_train_set(full_greek_all, full_greek_same,full_spain_all,full_spain_same ,
                                                 full_euroleague_all,full_euroleague_same,full_eurocup_all,
                                                 full_eurocup_same, baseline_greek_all, baseline_greek_same,
                                                 baseline_spain_all, baseline_spain_same, baseline_euroleague_all ,
                                                 baseline_euroleague_same, baseline_eurocup_all, baseline_eurocup_same, 
                                                 title, 'F1-Score', 'Mid-Season', loc=1,
                                                 letters_position=-0.045, ylimit=1.2)

plt.savefig('Figures/f1_comparison_train_set_mid_season.png')
plt.show()

# %% [markdown]
# ## Play-Offs

# %% [markdown]
# ### Brier Score

# %%
full_greek_all = [0.149,0.134,0.155,0.143]
full_greek_same = [0.148,0.132,0.125,0.132]
full_spain_all = [0.263,0.218,0.237,0.238]
full_spain_same = [0.251,0.232,0.217,0.229]
full_euroleague_all = [0.207,0.201,0.218,0.206]
full_euroleague_same = [0.226,0.192,0.206,0.204]
full_eurocup_all = [0.182,0.173,0.166,0.172]
full_eurocup_same = [0.191,0.165,0.179,0.174]


baseline_greek_all = [0.143,0.151,0.14,0.142]
baseline_greek_same = [0.16,0.197,0.202,0.169]
baseline_spain_all = [0.227,0.24,0.248,0.237]
baseline_spain_same = [0.195,0.221,0.194,0.19]
baseline_euroleague_all = [0.242,0.239,0.242,0.24]
baseline_euroleague_same = [0.221,0.283,0.26,0.246]
baseline_eurocup_all = [0.161,0.246,0.19,0.189]
baseline_eurocup_same = [0.206,0.168,0.213,0.189]

# %%
title = 'Play-Offs Brier Score \n Comparison The Length of Training Set'

plt = plot_papers().barplot_comparison_train_set(full_greek_all, full_greek_same,full_spain_all,full_spain_same ,
                                                 full_euroleague_all,full_euroleague_same,full_eurocup_all,
                                                 full_eurocup_same, baseline_greek_all, baseline_greek_same,
                                                 baseline_spain_all, baseline_spain_same, baseline_euroleague_all ,
                                                 baseline_euroleague_same, baseline_eurocup_all, baseline_eurocup_same, 
                                                 title, 'Brier Score', 'Regular Season', loc=1,
                                                 letters_position=-0.015, ylimit=0.4)

plt.savefig('Figures/bs_comparison_train_set_play_offs.png')
plt.show()

# %% [markdown]
# ### Accuracy

# %%
full_greek_all = [0.773,0.727,0.727,0.773]
full_greek_same = [0.818,0.773,0.864,0.818]
full_spain_all = [0.571,0.619,0.571,0.571]
full_spain_same = [0.571,0.524,0.667,0.571]
full_euroleague_all = [0.7,0.65,0.65,0.65]
full_euroleague_same = [0.65,0.7,0.75,0.75]
full_eurocup_all = [0.875,0.875,0.875,0.875]
full_eurocup_same = [0.75,0.75,0.688,0.75]


baseline_greek_all = [0.727,0.682,0.727,0.727]
baseline_greek_same = [0.727,0.727,0.636,0.773]
baseline_spain_all = [0.619,0.714,0.714,0.714]
baseline_spain_same = [0.714,0.714,0.714,0.714]
baseline_euroleague_all = [0.6,0.55,0.6,0.6]
baseline_euroleague_same = [0.7,0.6,0.65,0.65]
baseline_eurocup_all = [0.75,0.5,0.625,0.688]
baseline_eurocup_same = [0.688,0.75,0.688,0.75]

# %%
title = 'Play-Offs Accuracy \n Comparison The Length of Training Set'

plt = plot_papers().barplot_comparison_train_set(full_greek_all, full_greek_same,full_spain_all,full_spain_same ,
                                                 full_euroleague_all,full_euroleague_same,full_eurocup_all,
                                                 full_eurocup_same, baseline_greek_all, baseline_greek_same,
                                                 baseline_spain_all, baseline_spain_same, baseline_euroleague_all ,
                                                 baseline_euroleague_same, baseline_eurocup_all, baseline_eurocup_same, 
                                                 title, 'Accuracy', 'Regular Season', loc=1,
                                                 letters_position=-0.05, ylimit=1.3)

plt.savefig('Figures/acc_comparison_train_set_play_offs.png')
plt.show()

# %% [markdown]
# ### F1-score

# %%
full_greek_all = [0.828,0.786,0.786,0.828]
full_greek_same = [0.857,0.815,0.889,0.857]
full_spain_all = [0.71,0.733,0.71,0.71]
full_spain_same = [0.71,0.688,0.759,0.71]
full_euroleague_all = [0.813,0.759,0.774,0.774]
full_euroleague_same = [0.774,0.813,0.839,0.839]
full_eurocup_all = [0.917,0.917,0.917,0.917]
full_eurocup_same = [0.846,0.818,0.783,0.833]


baseline_greek_all = [0.8,0.741,0.8,0.8]
baseline_greek_same = [0.786,0.769,0.75,0.815]
baseline_spain_all = [0.667,0.769,0.769,0.769]
baseline_spain_same = [0.786,0.786,0.769,0.786]
baseline_euroleague_all = [0.714,0.667,0.714,0.714]
baseline_euroleague_same = [0.8,0.692,0.759,0.759]
baseline_eurocup_all = [0.818,0.556,0.625,0.762]
baseline_eurocup_same = [0.762,0.833,0.762,0.818]

# %%
title = 'Play-Offs F1-score \n Comparison The Length of Training Set'

plt = plot_papers().barplot_comparison_train_set(full_greek_all, full_greek_same,full_spain_all,full_spain_same ,
                                                 full_euroleague_all,full_euroleague_same,full_eurocup_all,
                                                 full_eurocup_same, baseline_greek_all, baseline_greek_same,
                                                 baseline_spain_all, baseline_spain_same, baseline_euroleague_all ,
                                                 baseline_euroleague_same, baseline_eurocup_all, baseline_eurocup_same, 
                                                 title, 'F1-score', 'Regular Season', loc=1,
                                                 letters_position=-0.05, ylimit=1.4)

plt.savefig('Figures/f1_comparison_train_set_play_offs.png')
plt.show()
