# %%
import numpy as np
import pandas as pd
pd.options.display.max_rows = None

# %%
greek = pd.read_csv('features_greek_league.csv',sep = ',').rename(columns={'Count':'Greek_League'})
liga_acb = pd.read_csv('features_liga_acb.csv',sep = ',').rename(columns={'Count':'Liga_ACB'})
euroleague = pd.read_csv('features_euroleague.csv',sep = ',').rename(columns={'Count':'Eurolegue'})
eurocup = pd.read_csv('features_eurocup.csv',sep = ',').rename(columns={'Count':'Eurocup'})

# %%
features = greek.merge(liga_acb.merge(euroleague.merge(eurocup,on=['feature_name'],how='outer'),
                           on=['feature_name'],how='outer'),on=['feature_name'],how='outer').fillna(0)

# %%
features['Sum'] = features.sum(axis=1)
features.head()
# Out:
#                        feature_name  Greek_League  Liga_ACB  Eurolegue  \
# 0                          pagerank           9.0       5.0        7.0
# 1  Current_form_Game_Score_received           9.0       2.0        5.0
# 2        Current_form_Play_received           8.0       0.0        3.0
# 3                       history_EFG           8.0       3.0        6.0
# 4                               elo           8.0       1.0        4.0
#
#    Eurocup   Sum
# 0      7.0  28.0
# 1      9.0  25.0
# 2      7.0  18.0
# 3      4.0  21.0
# 4      9.0  22.0

# %%
features[['Greek_League', 'Liga_ACB', 'Eurolegue','Eurocup']] = features[['Greek_League', 'Liga_ACB', 'Eurolegue','Eurocup']]/9

# %%
features['Mean'] = features['Sum']/36

# %%
features_sorted = features.sort_values(['Sum'],ascending=False).reset_index(drop=True).iloc[:110]
features_sorted['feature_name'][features_sorted['feature_name']=='Regular Season']='Phase'
features_sorted
# Out:
#                                    feature_name  Greek_League  Liga_ACB  \
# 0                                    pi_ratings      0.777778  0.888889
# 1                                      pagerank      1.000000  0.555556
# 2                            Current_form_EDiff      0.888889  0.333333
# 3              Current_form_Game_Score_received      1.000000  0.222222
# 4                       Current_form_pointsdiff      0.777778  0.555556
# 5                              Current_form_FIC      0.777778  0.555556
# 6                            history_Game_Score      0.777778  0.444444
# 7                                   history_FIC      0.777778  0.666667
# 8                             Current_form_Play      0.666667  0.666667
# 9       Current_form_Performance_Index_received      0.777778  0.444444
# 10                        history_Play_received      0.777778  0.222222
# 11                 Current_form_EFG_received_sd      0.666667  0.555556
# 12                                history_Ediff      0.888889  0.333333
# 13                 tradition_pointsdiff_general      0.777778  0.666667
# 14                           history_pointsdiff      0.777778  0.444444
# 15                   tradition_pointsdiff_match      0.666667  0.555556
# 16                 Current_form_FIC_received_sd      0.777778  0.555556
# 17                             Current_form_elo      0.777778  0.444444
# 18                                          elo      0.888889  0.111111
# 19                                  history_EFG      0.888889  0.333333
# 20                        Current_form_EDiff_sd      0.777778  0.222222
# 21                         Current_form_Play_sd      0.777778  0.333333
# 22                            Current_form_Ortg      0.777778  0.555556
# 23                          history_TS_received      0.777778  0.333333
# 24                               history_Points      0.777778  0.555556
# 25                    Current_form_FIC_received      0.666667  0.333333
# 26                                 history_Ortg      0.777778  0.333333
# 27                                 history_Drtg      0.777778  0.444444
# 28                          Current_form_Points      0.666667  0.444444
# 29                               history_winner      0.666667  0.444444
# 30                             history_Ediff_sd      0.777778  0.444444
# 31                                history_TS_sd      0.666667  0.333333
# 32                         history_EFG_received      0.666667  0.111111
# 33                          Current_form_winner      0.666667  0.333333
# 34                           Current_form_TS_sd      0.666667  0.222222
# 35                         Current_form_Drtg_sd      0.555556  0.444444
# 36                       Current_form_Points_sd      0.666667  0.111111
# 37                     tradition_winner_general      0.777778  0.666667
# 38                        history_pointsdiff_sd      0.777778  0.333333
# 39                 Current_form_Points_received      0.666667  0.222222
# 40                                 history_Play      0.777778  0.333333
# 41                      history_Points_received      0.666667  0.222222
# 42                     history_Play_received_sd      0.666667  0.222222
# 43                    history_Performance_Index      0.666667  0.000000
# 44                   history_Points_received_sd      0.666667  0.333333
# 45            Current_form_Performance_Index_sd      0.777778  0.111111
# 46                              Current_form_TS      0.666667  0.000000
# 47           history_Performance_Index_received      0.777778  0.111111
# 48                            Current_form_Drtg      0.777778  0.111111
# 49                      tradition_Ediff_general      0.666667  0.333333
# 50                   Current_form_pointsdiff_sd      0.666667  0.111111
# 51                  Current_form_TS_received_sd      0.666667  0.333333
# 52                          Current_form_EFG_sd      0.666667  0.222222
# 53                        tradition_Ediff_match      0.666667  0.333333
# 54                   Current_form_Play_received      0.888889  0.000000
# 55                      Current_form_Game_Score      0.666667  0.111111
# 56               Current_form_Performance_Index      0.777778  0.111111
# 57                      history_FIC_received_sd      0.666667  0.222222
# 58                      Current_form_pi_ratings      0.777778  0.000000
# 59                               history_EFG_sd      0.777778  0.222222
# 60                           Tournament_Play_sd      0.777778  0.333333
# 61                        history_Game_Score_sd      0.777778  0.222222
# 62                            history_Points_sd      0.777778  0.222222
# 63                                   history_TS      0.777778  0.444444
# 64                        Current_form_pagerank      0.777778  0.111111
# 65                       Tournament_home_winner      0.888889  0.333333
# 66              Current_form_Points_received_sd      0.777778  0.111111
# 67                              Tournament_Play      0.666667  0.555556
# 68                         history_FIC_received      0.666667  0.222222
# 69                         Current_form_Ortg_sd      0.666667  0.111111
# 70                             Tournament_TS_sd      0.666667  0.222222
# 71                          Tournament_EDiff_sd      0.666667  0.333333
# 72                  history_Game_Score_received      0.666667  0.111111
# 73                               Tournament_EFG      0.555556  0.222222
# 74   Current_form_Performance_Index_received_sd      0.555556  0.111111
# 75                Current_form_Play_received_sd      0.666667  0.222222
# 76               history_Game_Score_received_sd      0.666667  0.111111
# 77                  tradition_winner_last_match      0.555556  0.444444
# 78                       tradition_winner_match      0.555556  0.555556
# 79                       history_TS_received_sd      0.555556  0.333333
# 80                      history_EFG_received_sd      0.555556  0.111111
# 81          Current_form_Game_Score_received_sd      0.555556  0.111111
# 82                   Current_form_Game_Score_sd      0.555556  0.111111
# 83                             Current_form_EFG      0.666667  0.000000
# 84                        Tournament_Game_Score      0.666667  0.111111
# 85                          Current_form_FIC_sd      0.666667  0.111111
# 86                              Tournament_Drtg      0.666667  0.000000
# 87              tradition_pointsdiff_last_match      0.666667  0.333333
# 88                     Current_form_TS_received      0.666667  0.000000
# 89                     Tournament_Game_Score_sd      0.666667  0.222222
# 90           tradition_Ediff_between_last_match      0.666667  0.222222
# 91                              history_Ortg_sd      0.666667  0.222222
# 92                               history_FIC_sd      0.666667  0.222222
# 93                             Tournament_EDiff      0.555556  0.111111
# 94                    Current_form_EFG_received      0.666667  0.000000
# 95                         Tournament_Points_sd      0.777778  0.000000
# 96                            Tournament_FIC_sd      0.666667  0.111111
# 97                           Tournament_Drtg_sd      0.666667  0.222222
# 98                            Tournament_EFG_sd      0.666667  0.000000
# 58    0.444444  0.777778  18.0  0.500000
# 59    0.444444  0.555556  18.0  0.500000
# 60    0.333333  0.555556  18.0  0.500000
# 61    0.333333  0.666667  18.0  0.500000
# 62    0.333333  0.666667  18.0  0.500000
# 63    0.333333  0.444444  18.0  0.500000
# 64    0.444444  0.666667  18.0  0.500000
# 65    0.333333  0.444444  18.0  0.500000
# 66    0.444444  0.666667  18.0  0.500000
# 67    0.444444  0.333333  18.0  0.500000
# 68    0.333333  0.777778  18.0  0.500000
# 69    0.555556  0.666667  18.0  0.500000
# 70    0.555556  0.444444  17.0  0.472222
# 71    0.333333  0.555556  17.0  0.472222
# 72    0.444444  0.666667  17.0  0.472222
# 73    0.444444  0.666667  17.0  0.472222
# 74    0.444444  0.777778  17.0  0.472222
# 75    0.444444  0.555556  17.0  0.472222
# 76    0.444444  0.666667  17.0  0.472222
# 77    0.333333  0.444444  16.0  0.444444
# 78    0.333333  0.333333  16.0  0.444444
# 79    0.444444  0.444444  16.0  0.444444
# 80    0.333333  0.777778  16.0  0.444444
# 81    0.444444  0.666667  16.0  0.444444
# 82    0.444444  0.666667  16.0  0.444444
# 83    0.444444  0.666667  16.0  0.444444
# 84    0.444444  0.555556  16.0  0.444444
# 85    0.444444  0.555556  16.0  0.444444
# 86    0.555556  0.555556  16.0  0.444444
# 87    0.333333  0.444444  16.0  0.444444
# 88    0.333333  0.777778  16.0  0.444444
# 89    0.444444  0.444444  16.0  0.444444
# 90    0.333333  0.444444  15.0  0.416667
# 91    0.333333  0.444444  15.0  0.416667
# 92    0.333333  0.444444  15.0  0.416667
# 93    0.333333  0.666667  15.0  0.416667
# 94    0.333333  0.666667  15.0  0.416667
# 95    0.333333  0.555556  15.0  0.416667
# 96    0.333333  0.555556  15.0  0.416667
# 97    0.333333  0.444444  15.0  0.416667
# 98    0.444444  0.555556  15.0  0.416667
# 99    0.444444  0.555556  14.0  0.388889
# 100   0.444444  0.444444  14.0  0.388889
# 101   0.444444  0.444444  14.0  0.388889
# 102   0.333333  0.666667  14.0  0.388889
# 103   0.444444  0.444444  14.0  0.388889
# 104   0.333333  0.555556  14.0  0.388889
# 105   0.333333  0.333333  13.0  0.361111
# 106   0.444444  0.333333  12.0  0.333333
# 107   0.333333  0.444444  12.0  0.333333
# 108   0.333333  0.333333  12.0  0.333333
# 109   0.333333  0.333333  10.0  0.277778

# %%
features=features_sorted

# %%
features = features.round(2)

# %%
plot_data = features[features['Mean']>0.6].sort_values('Sum')

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)
features_names = plot_data['feature_name'].values
percenatge = plot_data['Mean'].values
ax.barh(features_names,percenatge)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
ax.xaxis.set_tick_params(labelsize=18)
ax.yaxis.set_tick_params(labelsize=18)

ax.set_xlabel('Percentage of Appearence', fontsize=18)
plt.title('Important Features',size=30)
plt.savefig('../Figures/Features_plot.png')
plt.show()

# %%
csv_data = features[['feature_name','Greek_League', 'Liga_ACB', 'Eurolegue','Eurocup', 'Mean']][features['Mean']>0.5]

# %%
#features[['Greek_League', 'Liga_ACB', 'Eurolegue',
       #'Eurocup', 'Sum']] = features[['Greek_League', 'Liga_ACB', 'Eurolegue','Eurocup', 'Sum']].astype(int)

# %%
csv_data.to_csv('import_features.csv',sep = ',',index = None, header=True)
